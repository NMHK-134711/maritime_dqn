# %%
import requests
import json
import os
from datetime import datetime, timedelta

# API 호출 함수
def fetch_tidal_data(service_key, date, hour, minute, min_x, max_x, min_y, max_y):
    url = "http://www.khoa.go.kr/api/oceangrid/tidalCurrentArea/search.do"
    params = {
        "ServiceKey": service_key,
        "Date": date,           # YYYYMMDD 형식
        "Hour": hour,           # 00~23
        "Minute": minute,       # 00~59
        "MinX": min_x,          # 최소 경도
        "MaxX": max_x,          # 최대 경도
        "MinY": min_y,          # 최소 위도
        "MaxY": max_y,          # 최대 위도
        "ResultType": "json"
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        return None

# 시간대별 데이터 수집 및 저장
def collect_and_save_data(service_key, start_time, end_time, interval_minutes, min_x, max_x, min_y, max_y, save_dir):
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    current_time = start_time
    while current_time <= end_time:
        date_str = current_time.strftime("%Y%m%d")
        hour_str = current_time.strftime("%H")
        minute_str = current_time.strftime("%M")
        
        data = fetch_tidal_data(service_key, date_str, hour_str, minute_str, min_x, max_x, min_y, max_y)
        if data:
            filename = f"tidal_{date_str}_{hour_str}{minute_str}.json"
            filepath = os.path.join(save_dir, filename)
            with open(filepath, 'w', encoding='utf-8') as f:
                json.dump(data, f, ensure_ascii=False, indent=4)
            
            # 요청 가능 횟수 추출
            req_info = data["result"]["meta"]["obs_last_req_cnt"]  # "800/20000" 형식
            remaining_requests = int(req_info.split('/')[0])
            total_requests = int(req_info.split('/')[1])
            
            print(f"Saved: {filepath} | Remaining requests: {remaining_requests}/{total_requests}")
        
        current_time += timedelta(minutes=interval_minutes)

# 실행 설정
SERVICE_KEY = "gX98NZY5MAfir4EdDGCjNA=="  # 본인 인증키로 교체
START_TIME = datetime(2018, 7, 23, 16, 30)    # 2018.01.01 00:00
END_TIME = datetime(2018, 12, 31, 23, 59)    # 2018.01.01 23:59
INTERVAL_MINUTES = 30  # 30분 간격
MIN_X, MAX_X = 120, 127  # 경도 범위
MIN_Y, MAX_Y = 30, 38        # 위도 범위
SAVE_DIR = r"C:\baramproject\tidal_database"

# 데이터 수집 실행
collect_and_save_data(SERVICE_KEY, START_TIME, END_TIME, INTERVAL_MINUTES, MIN_X, MAX_X, MIN_Y, MAX_Y, SAVE_DIR)
# Out:
# Saved: C:\baramproject\tidal_database\tidal_20180723_1630.json | Remaining requests: 10220/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_1700.json | Remaining requests: 10219/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_1730.json | Remaining requests: 10218/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_1800.json | Remaining requests: 10217/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_1830.json | Remaining requests: 10216/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_1900.json | Remaining requests: 10215/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_1930.json | Remaining requests: 10214/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_2000.json | Remaining requests: 10213/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_2030.json | Remaining requests: 10212/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_2100.json | Remaining requests: 10211/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_2130.json | Remaining requests: 10210/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_2200.json | Remaining requests: 10209/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_2230.json | Remaining requests: 10208/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_2300.json | Remaining requests: 10207/20000
# Saved: C:\baramproject\tidal_database\tidal_20180723_2330.json | Remaining requests: 10206/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0000.json | Remaining requests: 10205/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0030.json | Remaining requests: 10204/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0100.json | Remaining requests: 10203/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0130.json | Remaining requests: 10202/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0200.json | Remaining requests: 10201/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0230.json | Remaining requests: 10200/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0300.json | Remaining requests: 10199/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0330.json | Remaining requests: 10198/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0400.json | Remaining requests: 10197/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0430.json | Remaining requests: 10196/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0500.json | Remaining requests: 10195/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0530.json | Remaining requests: 10194/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0600.json | Remaining requests: 10193/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0630.json | Remaining requests: 10192/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0700.json | Remaining requests: 10191/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0730.json | Remaining requests: 10190/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0800.json | Remaining requests: 10189/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0830.json | Remaining requests: 10188/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0900.json | Remaining requests: 10187/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_0930.json | Remaining requests: 10186/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1000.json | Remaining requests: 10185/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1030.json | Remaining requests: 10184/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1100.json | Remaining requests: 10183/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1130.json | Remaining requests: 10182/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1200.json | Remaining requests: 10181/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1230.json | Remaining requests: 10180/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1300.json | Remaining requests: 10179/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1330.json | Remaining requests: 10178/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1400.json | Remaining requests: 10177/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1430.json | Remaining requests: 10176/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1500.json | Remaining requests: 10175/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1530.json | Remaining requests: 10174/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1600.json | Remaining requests: 10173/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1630.json | Remaining requests: 10172/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1700.json | Remaining requests: 10171/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1730.json | Remaining requests: 10170/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1800.json | Remaining requests: 10169/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1830.json | Remaining requests: 10168/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1900.json | Remaining requests: 10167/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_1930.json | Remaining requests: 10166/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_2000.json | Remaining requests: 10165/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_2030.json | Remaining requests: 10164/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_2100.json | Remaining requests: 10163/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_2130.json | Remaining requests: 10162/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_2200.json | Remaining requests: 10161/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_2230.json | Remaining requests: 10160/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_2300.json | Remaining requests: 10159/20000
# Saved: C:\baramproject\tidal_database\tidal_20180724_2330.json | Remaining requests: 10158/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0000.json | Remaining requests: 10157/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0030.json | Remaining requests: 10156/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0100.json | Remaining requests: 10155/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0130.json | Remaining requests: 10154/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0200.json | Remaining requests: 10153/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0230.json | Remaining requests: 10152/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0300.json | Remaining requests: 10151/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0330.json | Remaining requests: 10150/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0400.json | Remaining requests: 10149/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0430.json | Remaining requests: 10148/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0500.json | Remaining requests: 10147/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0530.json | Remaining requests: 10146/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0600.json | Remaining requests: 10145/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0630.json | Remaining requests: 10144/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0700.json | Remaining requests: 10143/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0730.json | Remaining requests: 10142/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0800.json | Remaining requests: 10141/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0830.json | Remaining requests: 10140/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0900.json | Remaining requests: 10139/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_0930.json | Remaining requests: 10138/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1000.json | Remaining requests: 10137/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1030.json | Remaining requests: 10136/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1100.json | Remaining requests: 10135/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1130.json | Remaining requests: 10134/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1200.json | Remaining requests: 10133/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1230.json | Remaining requests: 10132/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1300.json | Remaining requests: 10131/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1330.json | Remaining requests: 10130/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1400.json | Remaining requests: 10129/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1430.json | Remaining requests: 10128/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1500.json | Remaining requests: 10127/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1530.json | Remaining requests: 10126/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1600.json | Remaining requests: 10125/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1630.json | Remaining requests: 10124/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1700.json | Remaining requests: 10123/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1730.json | Remaining requests: 10122/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1800.json | Remaining requests: 10121/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1830.json | Remaining requests: 10120/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1900.json | Remaining requests: 10119/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_1930.json | Remaining requests: 10118/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_2000.json | Remaining requests: 10117/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_2030.json | Remaining requests: 10116/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_2100.json | Remaining requests: 10115/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_2130.json | Remaining requests: 10114/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_2200.json | Remaining requests: 10113/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_2230.json | Remaining requests: 10112/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_2300.json | Remaining requests: 10111/20000
# Saved: C:\baramproject\tidal_database\tidal_20180725_2330.json | Remaining requests: 10110/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0000.json | Remaining requests: 10109/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0030.json | Remaining requests: 10108/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0100.json | Remaining requests: 10107/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0130.json | Remaining requests: 10106/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0200.json | Remaining requests: 10105/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0230.json | Remaining requests: 10104/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0300.json | Remaining requests: 10103/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0330.json | Remaining requests: 10102/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0400.json | Remaining requests: 10101/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0430.json | Remaining requests: 10100/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0500.json | Remaining requests: 10099/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0530.json | Remaining requests: 10098/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0600.json | Remaining requests: 10097/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0630.json | Remaining requests: 10096/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0700.json | Remaining requests: 10095/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0730.json | Remaining requests: 10094/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0800.json | Remaining requests: 10093/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0830.json | Remaining requests: 10092/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0900.json | Remaining requests: 10091/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_0930.json | Remaining requests: 10090/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1000.json | Remaining requests: 10089/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1030.json | Remaining requests: 10088/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1100.json | Remaining requests: 10087/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1130.json | Remaining requests: 10086/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1200.json | Remaining requests: 10085/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1230.json | Remaining requests: 10084/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1300.json | Remaining requests: 10083/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1330.json | Remaining requests: 10082/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1400.json | Remaining requests: 10081/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1430.json | Remaining requests: 10080/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1500.json | Remaining requests: 10079/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1530.json | Remaining requests: 10078/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1600.json | Remaining requests: 10077/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1630.json | Remaining requests: 10076/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1700.json | Remaining requests: 10075/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1730.json | Remaining requests: 10074/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1800.json | Remaining requests: 10073/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1830.json | Remaining requests: 10072/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1900.json | Remaining requests: 10071/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_1930.json | Remaining requests: 10070/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_2000.json | Remaining requests: 10069/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_2030.json | Remaining requests: 10068/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_2100.json | Remaining requests: 10067/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_2130.json | Remaining requests: 10066/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_2200.json | Remaining requests: 10065/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_2230.json | Remaining requests: 10064/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_2300.json | Remaining requests: 10063/20000
# Saved: C:\baramproject\tidal_database\tidal_20180726_2330.json | Remaining requests: 10062/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0000.json | Remaining requests: 10061/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0030.json | Remaining requests: 10060/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0100.json | Remaining requests: 10059/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0130.json | Remaining requests: 10058/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0200.json | Remaining requests: 10057/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0230.json | Remaining requests: 10056/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0300.json | Remaining requests: 10055/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0330.json | Remaining requests: 10054/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0400.json | Remaining requests: 10053/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0430.json | Remaining requests: 10052/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0500.json | Remaining requests: 10051/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0530.json | Remaining requests: 10050/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0600.json | Remaining requests: 10049/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0630.json | Remaining requests: 10048/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0700.json | Remaining requests: 10047/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0730.json | Remaining requests: 10046/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0800.json | Remaining requests: 10045/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0830.json | Remaining requests: 10044/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0900.json | Remaining requests: 10043/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_0930.json | Remaining requests: 10042/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1000.json | Remaining requests: 10041/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1030.json | Remaining requests: 10040/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1100.json | Remaining requests: 10039/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1130.json | Remaining requests: 10038/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1200.json | Remaining requests: 10037/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1230.json | Remaining requests: 10036/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1300.json | Remaining requests: 10035/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1330.json | Remaining requests: 10034/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1400.json | Remaining requests: 10033/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1430.json | Remaining requests: 10032/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1500.json | Remaining requests: 10031/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1530.json | Remaining requests: 10030/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1600.json | Remaining requests: 10029/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1630.json | Remaining requests: 10028/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1700.json | Remaining requests: 10027/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1730.json | Remaining requests: 10026/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1800.json | Remaining requests: 10025/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1830.json | Remaining requests: 10024/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1900.json | Remaining requests: 10023/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_1930.json | Remaining requests: 10022/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_2000.json | Remaining requests: 10021/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_2030.json | Remaining requests: 10020/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_2100.json | Remaining requests: 10019/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_2130.json | Remaining requests: 10018/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_2200.json | Remaining requests: 10017/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_2230.json | Remaining requests: 10016/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_2300.json | Remaining requests: 10015/20000
# Saved: C:\baramproject\tidal_database\tidal_20180727_2330.json | Remaining requests: 10014/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0000.json | Remaining requests: 10013/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0030.json | Remaining requests: 10012/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0100.json | Remaining requests: 10011/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0130.json | Remaining requests: 10010/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0200.json | Remaining requests: 10009/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0230.json | Remaining requests: 10008/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0300.json | Remaining requests: 10007/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0330.json | Remaining requests: 10006/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0400.json | Remaining requests: 10005/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0430.json | Remaining requests: 10004/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0500.json | Remaining requests: 10003/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0530.json | Remaining requests: 10002/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0600.json | Remaining requests: 10001/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0630.json | Remaining requests: 10000/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0700.json | Remaining requests: 9999/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0730.json | Remaining requests: 9998/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0800.json | Remaining requests: 9997/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0830.json | Remaining requests: 9996/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0900.json | Remaining requests: 9995/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_0930.json | Remaining requests: 9994/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1000.json | Remaining requests: 9993/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1030.json | Remaining requests: 9992/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1100.json | Remaining requests: 9991/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1130.json | Remaining requests: 9990/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1200.json | Remaining requests: 9989/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1230.json | Remaining requests: 9988/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1300.json | Remaining requests: 9987/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1330.json | Remaining requests: 9986/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1400.json | Remaining requests: 9985/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1430.json | Remaining requests: 9984/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1500.json | Remaining requests: 9983/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1530.json | Remaining requests: 9982/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1600.json | Remaining requests: 9981/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1630.json | Remaining requests: 9980/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1700.json | Remaining requests: 9979/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1730.json | Remaining requests: 9978/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1800.json | Remaining requests: 9977/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1830.json | Remaining requests: 9976/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1900.json | Remaining requests: 9975/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_1930.json | Remaining requests: 9974/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_2000.json | Remaining requests: 9973/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_2030.json | Remaining requests: 9972/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_2100.json | Remaining requests: 9971/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_2130.json | Remaining requests: 9970/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_2200.json | Remaining requests: 9969/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_2230.json | Remaining requests: 9968/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_2300.json | Remaining requests: 9967/20000
# Saved: C:\baramproject\tidal_database\tidal_20180728_2330.json | Remaining requests: 9966/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0000.json | Remaining requests: 9965/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0030.json | Remaining requests: 9964/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0100.json | Remaining requests: 9963/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0130.json | Remaining requests: 9962/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0200.json | Remaining requests: 9961/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0230.json | Remaining requests: 9960/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0300.json | Remaining requests: 9959/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0330.json | Remaining requests: 9958/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0400.json | Remaining requests: 9957/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0430.json | Remaining requests: 9956/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0500.json | Remaining requests: 9955/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0530.json | Remaining requests: 9954/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0600.json | Remaining requests: 9953/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0630.json | Remaining requests: 9952/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0700.json | Remaining requests: 9951/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0730.json | Remaining requests: 9950/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0800.json | Remaining requests: 9949/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0830.json | Remaining requests: 9948/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0900.json | Remaining requests: 9947/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_0930.json | Remaining requests: 9946/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1000.json | Remaining requests: 9945/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1030.json | Remaining requests: 9944/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1100.json | Remaining requests: 9943/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1130.json | Remaining requests: 9942/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1200.json | Remaining requests: 9941/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1230.json | Remaining requests: 9940/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1300.json | Remaining requests: 9939/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1330.json | Remaining requests: 9938/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1400.json | Remaining requests: 9937/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1430.json | Remaining requests: 9936/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1500.json | Remaining requests: 9935/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1530.json | Remaining requests: 9934/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1600.json | Remaining requests: 9933/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1630.json | Remaining requests: 9932/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1700.json | Remaining requests: 9931/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1730.json | Remaining requests: 9930/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1800.json | Remaining requests: 9929/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1830.json | Remaining requests: 9928/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1900.json | Remaining requests: 9927/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_1930.json | Remaining requests: 9926/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_2000.json | Remaining requests: 9925/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_2030.json | Remaining requests: 9924/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_2100.json | Remaining requests: 9923/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_2130.json | Remaining requests: 9922/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_2200.json | Remaining requests: 9921/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_2230.json | Remaining requests: 9920/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_2300.json | Remaining requests: 9919/20000
# Saved: C:\baramproject\tidal_database\tidal_20180729_2330.json | Remaining requests: 9918/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0000.json | Remaining requests: 9917/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0030.json | Remaining requests: 9916/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0100.json | Remaining requests: 9915/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0130.json | Remaining requests: 9914/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0200.json | Remaining requests: 9913/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0230.json | Remaining requests: 9912/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0300.json | Remaining requests: 9911/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0330.json | Remaining requests: 9910/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0400.json | Remaining requests: 9909/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0430.json | Remaining requests: 9908/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0500.json | Remaining requests: 9907/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0530.json | Remaining requests: 9906/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0600.json | Remaining requests: 9905/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0630.json | Remaining requests: 9904/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0700.json | Remaining requests: 9903/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0730.json | Remaining requests: 9902/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0800.json | Remaining requests: 9901/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0830.json | Remaining requests: 9900/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0900.json | Remaining requests: 9899/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_0930.json | Remaining requests: 9898/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1000.json | Remaining requests: 9897/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1030.json | Remaining requests: 9896/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1100.json | Remaining requests: 9895/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1130.json | Remaining requests: 9894/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1200.json | Remaining requests: 9893/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1230.json | Remaining requests: 9892/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1300.json | Remaining requests: 9891/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1330.json | Remaining requests: 9890/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1400.json | Remaining requests: 9889/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1430.json | Remaining requests: 9888/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1500.json | Remaining requests: 9887/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1530.json | Remaining requests: 9886/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1600.json | Remaining requests: 9885/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1630.json | Remaining requests: 9884/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1700.json | Remaining requests: 9883/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1730.json | Remaining requests: 9882/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1800.json | Remaining requests: 9881/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1830.json | Remaining requests: 9880/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1900.json | Remaining requests: 9879/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_1930.json | Remaining requests: 9878/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_2000.json | Remaining requests: 9877/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_2030.json | Remaining requests: 9876/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_2100.json | Remaining requests: 9875/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_2130.json | Remaining requests: 9874/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_2200.json | Remaining requests: 9873/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_2230.json | Remaining requests: 9872/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_2300.json | Remaining requests: 9871/20000
# Saved: C:\baramproject\tidal_database\tidal_20180730_2330.json | Remaining requests: 9870/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0000.json | Remaining requests: 9869/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0030.json | Remaining requests: 9868/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0100.json | Remaining requests: 9867/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0130.json | Remaining requests: 9866/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0200.json | Remaining requests: 9865/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0230.json | Remaining requests: 9864/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0300.json | Remaining requests: 9863/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0330.json | Remaining requests: 9862/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0400.json | Remaining requests: 9861/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0430.json | Remaining requests: 9860/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0500.json | Remaining requests: 9859/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0530.json | Remaining requests: 9858/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0600.json | Remaining requests: 9857/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0630.json | Remaining requests: 9856/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0700.json | Remaining requests: 9855/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0730.json | Remaining requests: 9854/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0800.json | Remaining requests: 9853/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0830.json | Remaining requests: 9852/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0900.json | Remaining requests: 9851/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_0930.json | Remaining requests: 9850/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1000.json | Remaining requests: 9849/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1030.json | Remaining requests: 9848/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1100.json | Remaining requests: 9847/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1130.json | Remaining requests: 9846/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1200.json | Remaining requests: 9845/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1230.json | Remaining requests: 9844/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1300.json | Remaining requests: 9843/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1330.json | Remaining requests: 9842/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1400.json | Remaining requests: 9841/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1430.json | Remaining requests: 9840/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1500.json | Remaining requests: 9839/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1530.json | Remaining requests: 9838/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1600.json | Remaining requests: 9837/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1630.json | Remaining requests: 9836/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1700.json | Remaining requests: 9835/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1730.json | Remaining requests: 9834/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1800.json | Remaining requests: 9833/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1830.json | Remaining requests: 9832/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1900.json | Remaining requests: 9831/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_1930.json | Remaining requests: 9830/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_2000.json | Remaining requests: 9829/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_2030.json | Remaining requests: 9828/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_2100.json | Remaining requests: 9827/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_2130.json | Remaining requests: 9826/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_2200.json | Remaining requests: 9825/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_2230.json | Remaining requests: 9824/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_2300.json | Remaining requests: 9823/20000
# Saved: C:\baramproject\tidal_database\tidal_20180731_2330.json | Remaining requests: 9822/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0000.json | Remaining requests: 9821/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0030.json | Remaining requests: 9820/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0100.json | Remaining requests: 9819/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0130.json | Remaining requests: 9818/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0200.json | Remaining requests: 9817/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0230.json | Remaining requests: 9816/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0300.json | Remaining requests: 9815/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0330.json | Remaining requests: 9814/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0400.json | Remaining requests: 9813/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0430.json | Remaining requests: 9812/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0500.json | Remaining requests: 9811/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0530.json | Remaining requests: 9810/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0600.json | Remaining requests: 9809/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0630.json | Remaining requests: 9808/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0700.json | Remaining requests: 9807/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0730.json | Remaining requests: 9806/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0800.json | Remaining requests: 9805/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0830.json | Remaining requests: 9804/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0900.json | Remaining requests: 9803/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_0930.json | Remaining requests: 9802/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1000.json | Remaining requests: 9801/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1030.json | Remaining requests: 9800/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1100.json | Remaining requests: 9799/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1130.json | Remaining requests: 9798/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1200.json | Remaining requests: 9797/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1230.json | Remaining requests: 9796/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1300.json | Remaining requests: 9795/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1330.json | Remaining requests: 9794/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1400.json | Remaining requests: 9793/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1430.json | Remaining requests: 9792/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1500.json | Remaining requests: 9791/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1530.json | Remaining requests: 9790/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1600.json | Remaining requests: 9789/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1630.json | Remaining requests: 9788/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1700.json | Remaining requests: 9787/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1730.json | Remaining requests: 9786/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1800.json | Remaining requests: 9785/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1830.json | Remaining requests: 9784/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1900.json | Remaining requests: 9783/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_1930.json | Remaining requests: 9782/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_2000.json | Remaining requests: 9781/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_2030.json | Remaining requests: 9780/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_2100.json | Remaining requests: 9779/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_2130.json | Remaining requests: 9778/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_2200.json | Remaining requests: 9777/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_2230.json | Remaining requests: 9776/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_2300.json | Remaining requests: 9775/20000
# Saved: C:\baramproject\tidal_database\tidal_20180801_2330.json | Remaining requests: 9774/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0000.json | Remaining requests: 9773/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0030.json | Remaining requests: 9772/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0100.json | Remaining requests: 9771/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0130.json | Remaining requests: 9770/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0200.json | Remaining requests: 9769/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0230.json | Remaining requests: 9768/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0300.json | Remaining requests: 9767/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0330.json | Remaining requests: 9766/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0400.json | Remaining requests: 9765/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0430.json | Remaining requests: 9764/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0500.json | Remaining requests: 9763/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0530.json | Remaining requests: 9762/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0600.json | Remaining requests: 9761/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0630.json | Remaining requests: 9760/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0700.json | Remaining requests: 9759/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0730.json | Remaining requests: 9758/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0800.json | Remaining requests: 9757/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0830.json | Remaining requests: 9756/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0900.json | Remaining requests: 9755/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_0930.json | Remaining requests: 9754/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1000.json | Remaining requests: 9753/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1030.json | Remaining requests: 9752/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1100.json | Remaining requests: 9751/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1130.json | Remaining requests: 9750/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1200.json | Remaining requests: 9749/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1230.json | Remaining requests: 9748/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1300.json | Remaining requests: 9747/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1330.json | Remaining requests: 9746/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1400.json | Remaining requests: 9745/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1430.json | Remaining requests: 9744/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1500.json | Remaining requests: 9743/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1530.json | Remaining requests: 9742/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1600.json | Remaining requests: 9741/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1630.json | Remaining requests: 9740/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1700.json | Remaining requests: 9739/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1730.json | Remaining requests: 9738/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1800.json | Remaining requests: 9737/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1830.json | Remaining requests: 9736/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1900.json | Remaining requests: 9735/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_1930.json | Remaining requests: 9734/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_2000.json | Remaining requests: 9733/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_2030.json | Remaining requests: 9732/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_2100.json | Remaining requests: 9731/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_2130.json | Remaining requests: 9730/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_2200.json | Remaining requests: 9729/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_2230.json | Remaining requests: 9728/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_2300.json | Remaining requests: 9727/20000
# Saved: C:\baramproject\tidal_database\tidal_20180802_2330.json | Remaining requests: 9726/20000
# Saved: C:\baramproject\tidal_database\tidal_20180803_0000.json | Remaining requests: 9725/20000
# Saved: C:\baramproject\tidal_database\tidal_20180803_0030.json | Remaining requests: 9724/20000
# ...
# Saved: C:\baramproject\tidal_database\tidal_20181228_1300.json | Remaining requests: 2643/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1330.json | Remaining requests: 2642/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1400.json | Remaining requests: 2641/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1430.json | Remaining requests: 2640/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1500.json | Remaining requests: 2639/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1530.json | Remaining requests: 2638/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1600.json | Remaining requests: 2637/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1630.json | Remaining requests: 2636/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1700.json | Remaining requests: 2635/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1730.json | Remaining requests: 2634/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1800.json | Remaining requests: 2633/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1830.json | Remaining requests: 2632/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1900.json | Remaining requests: 2631/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_1930.json | Remaining requests: 2630/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_2000.json | Remaining requests: 2629/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_2030.json | Remaining requests: 2628/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_2100.json | Remaining requests: 2627/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_2130.json | Remaining requests: 2626/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_2200.json | Remaining requests: 2625/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_2230.json | Remaining requests: 2624/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_2300.json | Remaining requests: 2623/20000
# Saved: C:\baramproject\tidal_database\tidal_20181228_2330.json | Remaining requests: 2622/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0000.json | Remaining requests: 2621/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0030.json | Remaining requests: 2620/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0100.json | Remaining requests: 2619/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0130.json | Remaining requests: 2618/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0200.json | Remaining requests: 2617/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0230.json | Remaining requests: 2616/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0300.json | Remaining requests: 2615/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0330.json | Remaining requests: 2614/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0400.json | Remaining requests: 2613/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0430.json | Remaining requests: 2612/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0500.json | Remaining requests: 2611/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0530.json | Remaining requests: 2610/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0600.json | Remaining requests: 2609/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0630.json | Remaining requests: 2608/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0700.json | Remaining requests: 2607/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0730.json | Remaining requests: 2606/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0800.json | Remaining requests: 2605/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0830.json | Remaining requests: 2604/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0900.json | Remaining requests: 2603/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_0930.json | Remaining requests: 2602/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1000.json | Remaining requests: 2601/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1030.json | Remaining requests: 2600/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1100.json | Remaining requests: 2599/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1130.json | Remaining requests: 2598/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1200.json | Remaining requests: 2597/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1230.json | Remaining requests: 2596/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1300.json | Remaining requests: 2595/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1330.json | Remaining requests: 2594/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1400.json | Remaining requests: 2593/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1430.json | Remaining requests: 2592/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1500.json | Remaining requests: 2591/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1530.json | Remaining requests: 2590/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1600.json | Remaining requests: 2589/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1630.json | Remaining requests: 2588/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1700.json | Remaining requests: 2587/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1730.json | Remaining requests: 2586/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1800.json | Remaining requests: 2585/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1830.json | Remaining requests: 2584/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1900.json | Remaining requests: 2583/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_1930.json | Remaining requests: 2582/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_2000.json | Remaining requests: 2581/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_2030.json | Remaining requests: 2580/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_2100.json | Remaining requests: 2579/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_2130.json | Remaining requests: 2578/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_2200.json | Remaining requests: 2577/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_2230.json | Remaining requests: 2576/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_2300.json | Remaining requests: 2575/20000
# Saved: C:\baramproject\tidal_database\tidal_20181229_2330.json | Remaining requests: 2574/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0000.json | Remaining requests: 2573/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0030.json | Remaining requests: 2572/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0100.json | Remaining requests: 2571/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0130.json | Remaining requests: 2570/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0200.json | Remaining requests: 2569/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0230.json | Remaining requests: 2568/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0300.json | Remaining requests: 2567/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0330.json | Remaining requests: 2566/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0400.json | Remaining requests: 2565/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0430.json | Remaining requests: 2564/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0500.json | Remaining requests: 2563/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0530.json | Remaining requests: 2562/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0600.json | Remaining requests: 2561/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0630.json | Remaining requests: 2560/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0700.json | Remaining requests: 2559/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0730.json | Remaining requests: 2558/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0800.json | Remaining requests: 2557/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0830.json | Remaining requests: 2556/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0900.json | Remaining requests: 2555/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_0930.json | Remaining requests: 2554/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1000.json | Remaining requests: 2553/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1030.json | Remaining requests: 2552/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1100.json | Remaining requests: 2551/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1130.json | Remaining requests: 2550/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1200.json | Remaining requests: 2549/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1230.json | Remaining requests: 2548/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1300.json | Remaining requests: 2547/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1330.json | Remaining requests: 2546/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1400.json | Remaining requests: 2545/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1430.json | Remaining requests: 2544/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1500.json | Remaining requests: 2543/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1530.json | Remaining requests: 2542/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1600.json | Remaining requests: 2541/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1630.json | Remaining requests: 2540/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1700.json | Remaining requests: 2539/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1730.json | Remaining requests: 2538/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1800.json | Remaining requests: 2537/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1830.json | Remaining requests: 2536/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1900.json | Remaining requests: 2535/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_1930.json | Remaining requests: 2534/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_2000.json | Remaining requests: 2533/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_2030.json | Remaining requests: 2532/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_2100.json | Remaining requests: 2531/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_2130.json | Remaining requests: 2530/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_2200.json | Remaining requests: 2529/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_2230.json | Remaining requests: 2528/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_2300.json | Remaining requests: 2527/20000
# Saved: C:\baramproject\tidal_database\tidal_20181230_2330.json | Remaining requests: 2526/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0000.json | Remaining requests: 2525/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0030.json | Remaining requests: 2524/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0100.json | Remaining requests: 2523/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0130.json | Remaining requests: 2522/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0200.json | Remaining requests: 2521/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0230.json | Remaining requests: 2520/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0300.json | Remaining requests: 2519/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0330.json | Remaining requests: 2518/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0400.json | Remaining requests: 2517/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0430.json | Remaining requests: 2516/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0500.json | Remaining requests: 2515/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0530.json | Remaining requests: 2514/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0600.json | Remaining requests: 2513/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0630.json | Remaining requests: 2512/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0700.json | Remaining requests: 2511/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0730.json | Remaining requests: 2510/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0800.json | Remaining requests: 2509/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0830.json | Remaining requests: 2508/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0900.json | Remaining requests: 2507/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_0930.json | Remaining requests: 2506/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1000.json | Remaining requests: 2505/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1030.json | Remaining requests: 2504/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1100.json | Remaining requests: 2503/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1130.json | Remaining requests: 2502/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1200.json | Remaining requests: 2501/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1230.json | Remaining requests: 2500/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1300.json | Remaining requests: 2499/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1330.json | Remaining requests: 2498/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1400.json | Remaining requests: 2497/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1430.json | Remaining requests: 2496/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1500.json | Remaining requests: 2495/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1530.json | Remaining requests: 2494/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1600.json | Remaining requests: 2493/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1630.json | Remaining requests: 2492/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1700.json | Remaining requests: 2491/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1730.json | Remaining requests: 2490/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1800.json | Remaining requests: 2489/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1830.json | Remaining requests: 2488/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1900.json | Remaining requests: 2487/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_1930.json | Remaining requests: 2486/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_2000.json | Remaining requests: 2485/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_2030.json | Remaining requests: 2484/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_2100.json | Remaining requests: 2483/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_2130.json | Remaining requests: 2482/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_2200.json | Remaining requests: 2481/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_2230.json | Remaining requests: 2480/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_2300.json | Remaining requests: 2479/20000
# Saved: C:\baramproject\tidal_database\tidal_20181231_2330.json | Remaining requests: 2478/20000
